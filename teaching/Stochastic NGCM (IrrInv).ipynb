# %% [markdown]
# # NCGM w/ a Twist
#
# We've solved the stochastic NCGM already. Now, we want to see how this works with occasionally binding constraints. The model is the same stochastic NCGM, but with irreversible investment (i.e. gross investment is non-negative).
#
# ## The Set-Up
# The problem becomes
# $$
# \begin{align*}
#     V(k,z) & = \max_{k'}\frac{(zk^{\alpha} + (1-\delta)k - k')^{1-\sigma}}{1-\sigma} + \beta \sum_{z'}P(z'|z)V(k',z')\\
#     k' - (1-\delta)k &\geq 0.
# \end{align*}
# $$
#
# In our case, $z\in\{z_l,z_h\}$ and follows a Markov transition matrix with $P(z_h|z_h) = p$ and $P(z_l|z_l) = q$. For our purposes, we're going to choose $z_l = 0.2$, $z_h = 0.95$, $\alpha = 0.3$, $\beta = 0.96$, $\delta = 0.1$, $\sigma = 2$, $p = 0.7$, and $q = 0.6$.

# %% [markdown]
# ## Warm-Up: Use EGM to Solve It
#
# As a warm-up, we're going to solve this using EGM.

# %%
import numpy as np
import matplotlib.pyplot as plt
from jax import jit
from jax import lax, random, numpy as jnp

# %%
alp0, bet0, del0, ppp0, qqq0, sig0, zlo0, zhi0 = 0.3, 0.96, 0.1, 0.7, 0.6, 2.0, 1.0, 1.5
ss_kap     = alp0 * (zlo0 + (zhi0 - zlo0) * (1.0 - qqq0) / (2.0 - ppp0 - qqq0))
ss_kap    /= (1.0 / bet0 - (1.0 - del0))
ss_kap     = ss_kap ** (1.0 / (1.0 - alp0))
pi_mat   = np.array([[ppp0, 1.0 - ppp0], [1.0 - qqq0, qqq0]]).T
num_sims = 5000
kap = np.linspace(0.1, 200, num_sims)
kap_long = np.linspace(0.1, 200, 20 * num_sims)

# %%
def egm_ncgm(kgrid, max_its = 2000, tol = 1e-8):
    kp0 = np.zeros((len(kgrid), 2))
    ic0 = np.zeros((len(kgrid), 2))
    rts = np.zeros((len(kgrid), 2))
    kgs = np.concatenate((kgrid[:,np.newaxis], kgrid[:,np.newaxis]), axis = 1)
    ic0 = (kgs ** alp0) * np.array((zhi0, zlo0)) + (1.0 - del0) * kgs
    rts = alp0 * (kgs ** (alp0 - 1.0)) * np.array((zhi0, zlo0)) + (1.0 - del0)
    kp0 =  (1.0 - 0.1 * del0) * kgs
    for i in range(max_its):
        cg   = bet0 * (ic0 - kp0) ** (-sig0) * rts
        cg   = (cg @ pi_mat) ** (-1.0 / sig0)
        cohg = cg + kgs
        kpnew = np.zeros_like(kp0)
        kpnew[:,0] = np.interp(ic0[:,0], cohg[:,0], kgrid)
        kpnew[:,1] = np.interp(ic0[:,1], cohg[:,1], kgrid)
        kp1 = np.maximum(kpnew - (1.0 - del0) * kgs, 0.0) + (1.0 - del0) * kgs
        dev = np.max(np.abs(kp1 - kp0))
        if dev < tol:
            print(dev)
            print(i)
            return kp1
        kp0 = kp1
    print("Warning! Maximum Number of Iterations Reached!")
    return kp0

# %%
egm_sol = egm_ncgm(kap)
egm_sol_long = egm_ncgm(kap_long)
# Out:
# 9.496749164839002e-09
# 94
# 9.531129663287174e-09
# 94

# %%
plt.plot(np.log(kap_long), np.log(egm_sol_long[:,1]) - np.log(1.0 - del0) - np.log(kap_long), 'm')
plt.plot(np.log(kap_long), np.log(egm_sol_long[:,0]) - np.log(1.0 - del0) - np.log(kap_long), 'c')
plt.plot(np.log(kap), np.log(egm_sol[:,1]) - np.log(1.0 - del0) - np.log(kap), 'g--')
plt.plot(np.log(kap), np.log(egm_sol[:,0]) - np.log(1.0 - del0) - np.log(kap), 'b--')

# %% [markdown]
# ## Use Neural Nets to Solve It
#
# First, we import some packages.

# %%
import jax
import jaxopt
from optax import sgd, adam, adabelief, apply_updates
from typing import Any, Callable, Sequence
from jax import grad, value_and_grad
from flax.core import freeze, unfreeze
from flax import linen as nn

# %% [markdown]
# ### Define and Initialize the Neural Nets

# %%
class ExplicitMLP(nn.Module):
    features: Sequence[int]

    def setup(self):
        self.layers = [nn.Dense(feat) for feat in self.features]
        
    def __call__(self, inputs):
        x = inputs
        for i, lyr in enumerate(self.layers):
            x = lyr(x)
            if i != len(self.layers) - 1:
                 x = jnp.tanh(x)
        return x

# %%
key1, key2 = random.split(random.PRNGKey(8675309), 2)
x = random.uniform(key1, (4,2))

# %%
g_inner  = ExplicitMLP(features=[8,8,1])

params = g_inner.init(key2, x)

print('initialized parameter shapes:\n', jax.tree_util.tree_map(jnp.shape, unfreeze(params)))
# Out:
# initialized parameter shapes:
#  {'params': {'layers_0': {'bias': (8,), 'kernel': (2, 8)}, 'layers_1': {'bias': (8,), 'kernel': (8, 8)}, 'layers_2': {'bias': (1,), 'kernel': (8, 1)}}}

# %% [markdown]
# ### Wrap the Network to Get Policy Function and Multiplier

# %%
@jit
def g_approx(params, x):
    inner_g = nn.sigmoid(g_inner.apply(params, x))
    income  = x[:,1] * x[:,0] ** alp0 + (1.0 - del0) * x[:,0]
    return inner_g * income[:,jnp.newaxis]

# %%
# %time g2_1 = g_approx(params, np.concatenate((kap[:,np.newaxis],np.ones((len(kap),1))), axis = 1))
# %time g2_15 = g_approx(params, np.concatenate((kap[:,np.newaxis], 1.5 * np.ones((len(kap),1))), axis = 1))
# Out:
# CPU times: user 50.7 ms, sys: 4.84 ms, total: 55.5 ms
# Wall time: 45.1 ms
# CPU times: user 183 μs, sys: 46 μs, total: 229 μs
# Wall time: 232 μs

# %% [markdown]
# Now, see what it looks like at the beginning.

# %%
plt.plot(np.log(kap), np.log(g2_1[:,0]) - np.log(1.0 - del0) - np.log(kap), 'r')
plt.plot(np.log(kap), np.log(g2_15[:,0]) - np.log(1.0 - del0) - np.log(kap), 'c')
plt.plot(np.log(kap), np.log(egm_sol[:,1]) - np.log(1.0 - del0) - np.log(kap), 'g--')
plt.plot(np.log(kap), np.log(egm_sol[:,0]) - np.log(1.0 - del0) - np.log(kap), 'b--')

# %% [markdown]
# ### Define the Loss Function

# %%
@jit
def our_loss(params):
    # draw (k, z) from set and form into matrix 'xs' 
    ks = np.exp(np.random.uniform(-4.0, 5.0, (num_sims, 1)))
    zs = np.random.binomial(1, 0.5, (num_sims, 1))
    ps = (1.0 - qqq0) * np.ones((num_sims, 1)) + (ppp0 + qqq0 - 1.0) * zs
    zs = zlo0 + (zhi0 - zlo0) * zs
    xs = np.concatenate((ks, zs), axis = 1)
    
    # compute k' and c
    kp = g_approx(params, xs)
    c0 = zs * ks ** alp0 + (1.0 - del0) * ks - kp
    
    # compute k'' and c' for both realizations of z'
    kpph = g_approx(params, jnp.concatenate((kp, zhi0 * jnp.ones((num_sims, 1))), axis = 1))
    kppl = g_approx(params, jnp.concatenate((kp, zlo0 * jnp.ones((num_sims, 1))), axis = 1))
    cph  = zhi0 * kp ** alp0 + (1.0 - del0) * kp - kpph
    cpl  = zlo0 * kp ** alp0 + (1.0 - del0) * kp - kppl
    
    # compute r' for both realizations of z'
    rh = alp0 * zhi0 * kp ** (alp0 - 1.0) + (1.0 - del0)
    rl = alp0 * zlo0 * kp ** (alp0 - 1.0) + (1.0 - del0)
    
    # compute expectation of future
    efut = bet0 * (ps * rh * cph ** (-sig0) + (1.0 - ps) * rl * cpl ** (-sig0))
    aval = 7.0 * (1.0 - (1.0 - del0) * ks / kp)
    hval = 1.0 - efut  * c0 ** (sig0)
    fbvl = aval + hval - jnp.sqrt(aval ** 2.0 + hval ** 2.0)
    
    return jnp.sqrt(jnp.mean(fbvl ** 2.0))

# %%
# %time our_loss(params)
# Out:
# CPU times: user 162 ms, sys: 161 ms, total: 323 ms
# Wall time: 135 ms
# Array(10.25313, dtype=float32)

# %% [markdown]
# ### Defining the Optimization Algorithm and Fitting

# %%
tx = adam(learning_rate=1e-3)
opt_state = tx.init(params)
loss_grad_fn = jit(value_and_grad(our_loss, 0))
ud = jit(tx.update)
apply_updatesj = jit(apply_updates)

# %%
for i in range(100001):
    loss_val, grads = loss_grad_fn(params)
    updates, opt_state = ud(grads, opt_state)
    params = apply_updatesj(params, updates)
    if i % 10000 == 0:
        print('Loss step {}: '.format(i), loss_val)
# Out:
# Loss step 0:  10.25313
# Loss step 10000:  0.0030742083
# Loss step 20000:  0.0020321836
# Loss step 30000:  0.0014627315
# Loss step 40000:  0.0011627141
# Loss step 50000:  0.0010363243
# Loss step 60000:  0.0009546138
# Loss step 70000:  0.00078393484
# Loss step 80000:  0.0009936765
# Loss step 90000:  0.0009862715
# Loss step 100000:  0.0020202154

# %% [markdown]
# ### Checking Fit at the End

# %%
g2_1 = g_approx(params, np.concatenate((kap[:,np.newaxis],np.ones((len(kap),1))), axis = 1))
g2_15 = g_approx(params, np.concatenate((kap[:,np.newaxis], 1.5 * np.ones((len(kap),1))), axis = 1))

# %% [markdown]
# Now, see what it looks like at the end.

# %%
plt.plot(np.log(kap), np.log(g2_1[:,0]) - np.log(1.0 - del0) - np.log(kap), 'r')
plt.plot(np.log(kap), np.log(g2_15[:,0]) - np.log(1.0 - del0) - np.log(kap), 'c')
plt.plot(np.log(kap), np.log(egm_sol[:,1]) - np.log(1.0 - del0) - np.log(kap), 'g--')
plt.plot(np.log(kap), np.log(egm_sol[:,0]) - np.log(1.0 - del0) - np.log(kap), 'b--')

# %%
plt.plot(np.log(kap), np.log10(np.abs(np.log(egm_sol[:,1] / g2_1[:,0]))), 'r')
plt.plot(np.log(kap), np.log10(np.abs(np.log(egm_sol[:,0] / g2_15[:,0]))), 'c')

# %%
plt.plot(np.log(kap), np.log10(np.abs(np.log(egm_sol_long[::20,1] / g2_1[:,0]))), 'r')
plt.plot(np.log(kap), np.log10(np.abs(np.log(egm_sol_long[::20,0] / g2_15[:,0]))), 'c')
